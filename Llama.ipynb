# %%
import getpass
import os

if "GROQ_API_KEY" not in os.environ:
    os.environ["GROQ_API_KEY"] = getpass.getpass("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
")
# Out:
#   Input In [14]
#     os.environ["GROQ_API_KEY"] = getpass.getpass("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
#                                                                                                           ^
# SyntaxError: EOL while scanning string literal

# %%
# %pip install -qU langchain-groq
# %pip install -qU langchain
# Out:
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="llama-3.1-70b-versatile",
    temperature=0,
    groq_api_key="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"
     
)
response=llm.invoke("does god exist")
print(response[content])
# Out:
# content="The question of whether God exists is a complex and debated topic among philosophers, theologians, scientists, and many others. There is no definitive answer, as it ultimately depends on one's personal beliefs, cultural background, and worldview. Here's a balanced overview of the main arguments:\n\n**Arguments for the existence of God:**\n\n1. **The Cosmological Argument**: This argument posits that everything that exists has a cause, and since the universe exists, it must have a cause, which is God.\n2. **The Teleological Argument**: This argument suggests that the complexity and order in the universe imply the existence of a designer or creator, which is God.\n3. **The Ontological Argument**: This argument, proposed by St. Anselm, states that God's existence can be deduced from the concept of God as a perfect being.\n4. **The Moral Argument**: This argument asserts that the existence of objective moral values and duties implies the existence of a moral lawgiver, which is God.\n5. **Personal Experiences**: Many people claim to have had personal experiences of God's presence, guidance, or intervention in their lives.\n\n**Arguments against the existence of God:**\n\n1. **The Problem of Evil**: This argument questions why an all-powerful, all-knowing, and all-good God would allow evil and suffering to exist in the world.\n2. **The Argument from Naturalism**: This argument posits that natural laws and processes can explain the complexity and order in the universe, making God unnecessary.\n3. **The Argument from Inconsistency**: This argument highlights the contradictions and inconsistencies within religious texts and traditions.\n4. **The Lack of Empirical Evidence**: There is no empirical evidence to support the existence of God, and many scientific discoveries have challenged traditional religious beliefs.\n5. **The Argument from Parsimony**: This argument suggests that God is an unnecessary hypothesis, as natural laws and processes can explain the world without invoking a divine being.\n\n**Neutral perspectives:**\n\n1. **Agnosticism**: This perspective holds that the existence or non-existence of God is unknown or unknowable.\n2. **Deism**: This perspective posits that God created the universe but does not intervene in its workings.\n3. **Pantheism**: This perspective identifies God with the universe itself, rather than a separate entity.\n\nUltimately, the question of whether God exists is a matter of personal faith, philosophical interpretation, and individual perspective. While there are valid arguments on both sides, there is no conclusive evidence to prove or disprove the existence of God." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 522, 'prompt_tokens': 38, 'total_tokens': 560, 'completion_time': 2.088, 'prompt_time': 0.007544578, 'queue_time': 0.008012992, 'total_time': 2.095544578}, 'model_name': 'llama-3.1-70b-versatile', 'system_fingerprint': 'fp_5c5d1b5cfb', 'finish_reason': 'stop', 'logprobs': None} id='run-a9717372-2009-4aff-9501-286af562dfee-0' usage_metadata={'input_tokens': 38, 'output_tokens': 522, 'total_tokens': 560}

# %%
print(response.content)
# Out:
# The question of whether God exists is a complex and debated topic among philosophers, theologians, scientists, and many others. There is no definitive answer, as it ultimately depends on one's personal beliefs, cultural background, and worldview. Here's a balanced overview of the main arguments:
#
# **Arguments for the existence of God:**
#
# 1. **The Cosmological Argument**: This argument posits that everything that exists has a cause, and since the universe exists, it must have a cause, which is God.
# 2. **The Teleological Argument**: This argument suggests that the complexity and order in the universe imply the existence of a designer or creator, which is God.
# 3. **The Ontological Argument**: This argument, proposed by St. Anselm, states that God's existence can be deduced from the concept of God as a perfect being.
# 4. **The Moral Argument**: This argument asserts that the existence of objective moral values and duties implies the existence of a moral lawgiver, which is God.
# 5. **Personal Experiences**: Many people claim to have had personal experiences of God's presence, guidance, or intervention in their lives.
#
# **Arguments against the existence of God:**
#
# 1. **The Problem of Evil**: This argument questions why an all-powerful, all-knowing, and all-good God would allow evil and suffering to exist in the world.
# 2. **The Argument from Naturalism**: This argument posits that natural laws and processes can explain the complexity and order in the universe, making God unnecessary.
# 3. **The Argument from Inconsistency**: This argument highlights the contradictions and inconsistencies within religious texts and traditions.
# 4. **The Lack of Empirical Evidence**: There is no empirical evidence to support the existence of God, and many scientific discoveries have challenged traditional religious beliefs.
# 5. **The Argument from Parsimony**: This argument suggests that God is an unnecessary hypothesis, as natural laws and processes can explain the world without invoking a divine being.
#
# **Neutral perspectives:**
#
# 1. **Agnosticism**: This perspective holds that the existence or non-existence of God is unknown or unknowable.
# 2. **Deism**: This perspective posits that God created the universe but does not intervene in its workings.
# 3. **Pantheism**: This perspective identifies God with the universe itself, rather than a separate entity.
#
# Ultimately, the question of whether God exists is a matter of personal faith, philosophical interpretation, and individual perspective. While there are valid arguments on both sides, there is no conclusive evidence to prove or disprove the existence of God.

# %%
# !pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-0.5.20-py3-none-any.whl.metadata (6.8 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Using cached build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pydantic>=1.9 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (2.10.2)
# Collecting chroma-hnswlib==0.7.6 (from chromadb)
#   Downloading chroma_hnswlib-0.7.6-cp39-cp39-macosx_10_9_x86_64.whl.metadata (252 bytes)
# Collecting fastapi>=0.95.2 (from chromadb)
#   Downloading fastapi-0.115.5-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvicorn-0.32.1-py3-none-any.whl.metadata (6.6 kB)
# Collecting numpy>=1.22.5 (from chromadb)
#   Downloading numpy-2.0.2-cp39-cp39-macosx_10_9_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 1.6 MB/s eta 0:00:00
# Collecting posthog>=2.4.0 (from chromadb)
#   Downloading posthog-3.7.3-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.16.3-cp39-cp39-macosx_10_15_x86_64.whl.metadata (4.3 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.28.2-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.28.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Downloading opentelemetry_instrumentation_fastapi-0.49b2-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.28.2-py3-none-any.whl.metadata (1.5 kB)
# Collecting tokenizers>=0.13.2 (from chromadb)
#   Downloading tokenizers-0.20.4-cp39-abi3-macosx_10_12_x86_64.whl.metadata (6.7 kB)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 1.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting tqdm>=4.65.0 (from chromadb)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 1.7 MB/s eta 0:00:00
# Collecting overrides>=7.3.1 (from chromadb)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb)
#   Downloading importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Collecting grpcio>=1.58.0 (from chromadb)
#   Downloading grpcio-1.68.0-cp39-cp39-macosx_10_9_universal2.whl.metadata (3.9 kB)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.2.1-cp39-abi3-macosx_10_12_universal2.whl.metadata (9.8 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Downloading typer-0.13.1-py3-none-any.whl.metadata (15 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-31.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (6.0)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.0.1-cp39-cp39-macosx_10_9_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (3.10.12)
# Requirement already satisfied: httpx>=0.27.0 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from chromadb) (0.27.2)
# Collecting rich>=10.11.0 (from chromadb)
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: packaging>=19.1 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (24.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: importlib-metadata>=4.6 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (4.11.3)
# Requirement already satisfied: tomli>=1.1.0 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (1.2.2)
# Collecting starlette<0.42.0,>=0.40.0 (from fastapi>=0.95.2->chromadb)
#   Downloading starlette-0.41.3-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: anyio in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (3.5.0)
# Requirement already satisfied: certifi in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (2021.10.8)
# Requirement already satisfied: httpcore==1.* in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (1.0.7)
# Requirement already satisfied: idna in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (3.3)
# Requirement already satisfied: sniffio in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.33.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: requests in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.27.1)
# Requirement already satisfied: requests-oauthlib in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3>=1.24.2 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.26.9)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (2.0.7)
# Requirement already satisfied: protobuf in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (3.19.1)
# Requirement already satisfied: sympy in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (1.10.1)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading Deprecated-1.2.15-py2.py3-none-any.whl.metadata (5.5 kB)
# Collecting importlib-metadata>=4.6 (from build>=1.0.3->chromadb)
#   Downloading importlib_metadata-8.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.53.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.28.2 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.28.2-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.28.2 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.28.2-py3-none-any.whl.metadata (2.3 kB)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb)
#   Downloading protobuf-5.28.3-cp38-abi3-macosx_10_9_universal2.whl.metadata (592 bytes)
# Collecting opentelemetry-instrumentation-asgi==0.49b2 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation_asgi-0.49b2-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-instrumentation==0.49b2 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation-0.49b2-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-semantic-conventions==0.49b2 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.49b2-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-util-http==0.49b2 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_util_http-0.49b2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-instrumentation==0.49b2->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.12.1)
# Requirement already satisfied: asgiref~=3.0 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from opentelemetry-instrumentation-asgi==0.49b2->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from pydantic>=1.9->chromadb) (2.27.1)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->chromadb)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting pygments<3.0.0,>=2.13.0 (from rich>=10.11.0->chromadb)
#   Using cached pygments-2.18.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting huggingface-hub<1.0,>=0.16.4 (from tokenizers>=0.13.2->chromadb)
#   Downloading huggingface_hub-0.26.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: click>=8.0.0 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from typer>=0.9.0->chromadb) (8.0.4)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.6.4-cp39-cp39-macosx_10_9_universal2.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvloop-0.21.0-cp39-cp39-macosx_10_9_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-1.0.0-cp39-cp39-macosx_10_12_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-14.1-cp39-cp39-macosx_10_9_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: zipp>=3.1.0 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from importlib-resources->chromadb) (3.7.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: setuptools>=40.3.0 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (67.8.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.7.2)
# Requirement already satisfied: filelock in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.12.2)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb)
#   Downloading fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Collecting zipp>=3.1.0 (from importlib-resources->chromadb)
#   Downloading zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from requests->kubernetes>=28.1.0->chromadb) (2.0.4)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath>=0.19 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.2.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/samarthraipal/opt/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Downloading chromadb-0.5.20-py3-none-any.whl (617 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 617.9/617.9 kB 720.0 kB/s eta 0:00:0000:0100:01
# Downloading chroma_hnswlib-0.7.6-cp39-cp39-macosx_10_9_x86_64.whl (195 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.9/195.9 kB 853.5 kB/s eta 0:00:0000:0100:01
# Downloading bcrypt-4.2.1-cp39-abi3-macosx_10_12_universal2.whl (489 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 489.8/489.8 kB 842.6 kB/s eta 0:00:00a 0:00:01
# Using cached build-1.2.2.post1-py3-none-any.whl (22 kB)
# Downloading fastapi-0.115.5-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 686.6 kB/s eta 0:00:00a 0:00:01
# Downloading grpcio-1.68.0-cp39-cp39-macosx_10_9_universal2.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 861.5 kB/s eta 0:00:0000:0100:01
# Downloading kubernetes-31.0.0-py2.py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 1.1 MB/s eta 0:00:0000:0100:010m
# Downloading mmh3-5.0.1-cp39-cp39-macosx_10_9_x86_64.whl (38 kB)
# Downloading numpy-2.0.2-cp39-cp39-macosx_10_9_x86_64.whl (21.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.2/21.2 MB 1.1 MB/s eta 0:00:0000:0100:01m
# Downloading onnxruntime-1.16.3-cp39-cp39-macosx_10_15_x86_64.whl (7.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 1.1 MB/s eta 0:00:0000:0100:01
# Downloading opentelemetry_api-1.28.2-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 412.0 kB/s eta 0:00:00a 0:00:01
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.28.2-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.28.2-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.28.2-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 679.2 kB/s eta 0:00:00a 0:00:01
# Downloading opentelemetry_instrumentation_fastapi-0.49b2-py3-none-any.whl (12 kB)
# Downloading opentelemetry_instrumentation-0.49b2-py3-none-any.whl (30 kB)
# Downloading opentelemetry_instrumentation_asgi-0.49b2-py3-none-any.whl (16 kB)
# Downloading opentelemetry_semantic_conventions-0.49b2-py3-none-any.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.2/159.2 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Downloading opentelemetry_util_http-0.49b2-py3-none-any.whl (6.9 kB)
# Downloading opentelemetry_sdk-1.28.2-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.8/118.8 kB 728.5 kB/s eta 0:00:00a 0:00:01
# Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading posthog-3.7.3-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 kB 808.8 kB/s eta 0:00:000:00:01
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.4/242.4 kB 990.1 kB/s eta 0:00:00 0:00:01m
# Downloading tokenizers-0.20.4-cp39-abi3-macosx_10_12_x86_64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 1.7 MB/s eta 0:00:0000:0100:01
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 1.5 MB/s eta 0:00:00a 0:00:01
# Downloading typer-0.13.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 1.4 MB/s eta 0:00:00
# Downloading uvicorn-0.32.1-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Downloading importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading Deprecated-1.2.15-py2.py3-none-any.whl (9.9 kB)
# Downloading durationpy-0.9-py3-none-any.whl (3.5 kB)
# Downloading httptools-0.6.4-cp39-cp39-macosx_10_9_universal2.whl (201 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.1/201.1 kB 422.7 kB/s eta 0:00:00 0:00:01
# Downloading huggingface_hub-0.26.2-py3-none-any.whl (447 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.5/447.5 kB 756.3 kB/s eta 0:00:00a 0:00:01
# Downloading importlib_metadata-8.5.0-py3-none-any.whl (26 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Downloading protobuf-5.28.3-cp38-abi3-macosx_10_9_universal2.whl (414 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 414.7/414.7 kB 663.9 kB/s eta 0:00:0000:0100:01
# Using cached pygments-2.18.0-py3-none-any.whl (1.2 MB)
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading starlette-0.41.3-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 899.8 kB/s eta 0:00:000:00:01
# Downloading uvloop-0.21.0-cp39-cp39-macosx_10_9_x86_64.whl (800 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.9/800.9 kB 1.3 MB/s eta 0:00:0000:0100:01
# Downloading watchfiles-1.0.0-cp39-cp39-macosx_10_12_x86_64.whl (394 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.1/394.1 kB 1.6 MB/s eta 0:00:00a 0:00:01
# Downloading websockets-14.1-cp39-cp39-macosx_10_9_x86_64.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.6/159.6 kB 2.0 MB/s eta 0:00:00 0:00:01
# Downloading zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.2 MB/s eta 0:00:00
# Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading fsspec-2024.10.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.6/179.6 kB 971.8 kB/s eta 0:00:00 0:00:01
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 638.8 kB/s eta 0:00:00a 0:00:01
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53725 sha256=a36f46f7758c8fa96fa242cab374f7465c911e107737528360dd9a6827c23c0e
#   Stored in directory: /Users/samarthraipal/Library/Caches/pip/wheels/f7/02/64/d541eac67ec459309d1fb19e727f58ecf7ffb4a8bf42d4cfe5
# Successfully built pypika
# Installing collected packages: pypika, monotonic, durationpy, zipp, websockets, uvloop, uvicorn, tqdm, shellingham, python-dotenv, pyproject_hooks, pygments, protobuf, overrides, opentelemetry-util-http, oauthlib, numpy, mmh3, mdurl, humanfriendly, httptools, grpcio, fsspec, deprecated, bcrypt, backoff, watchfiles, starlette, posthog, opentelemetry-proto, markdown-it-py, importlib-resources, importlib-metadata, huggingface-hub, coloredlogs, chroma-hnswlib, tokenizers, rich, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, onnxruntime, kubernetes, fastapi, build, typer, opentelemetry-semantic-conventions, opentelemetry-sdk, opentelemetry-instrumentation, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb
#   Attempting uninstall: zipp
#     Found existing installation: zipp 3.7.0
#     Uninstalling zipp-3.7.0:
#       Successfully uninstalled zipp-3.7.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.64.0
#     Uninstalling tqdm-4.64.0:
#       Successfully uninstalled tqdm-4.64.0
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.11.2
#     Uninstalling Pygments-2.11.2:
#       Successfully uninstalled Pygments-2.11.2
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.1
#     Uninstalling protobuf-3.19.1:
#       Successfully uninstalled protobuf-3.19.1
#   Attempting uninstall: oauthlib
#     Found existing installation: oauthlib 3.2.1
#     Uninstalling oauthlib-3.2.1:
#       Successfully uninstalled oauthlib-3.2.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.42.0
#     Uninstalling grpcio-1.42.0:
#       Successfully uninstalled grpcio-1.42.0
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2022.2.0
#     Uninstalling fsspec-2022.2.0:
#       Successfully uninstalled fsspec-2022.2.0
#   Attempting uninstall: bcrypt
#     Found existing installation: bcrypt 3.2.0
#     Uninstalling bcrypt-3.2.0:
#       Successfully uninstalled bcrypt-3.2.0
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.11.3
#     Uninstalling importlib-metadata-4.11.3:
#       Successfully uninstalled importlib-metadata-4.11.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# daal4py 2021.5.0 requires daal==2021.4.0, which is not installed.
# spyder 5.1.5 requires pyqt5<5.13, which is not installed.
# spyder 5.1.5 requires pyqtwebengine<5.13, which is not installed.
# langchain 0.3.8 requires numpy<2,>=1.22.4; python_version < "3.12", but you have numpy 2.0.2 which is incompatible.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 2.0.2 which is incompatible.
# scipy 1.7.3 requires numpy<1.23.0,>=1.16.5, but you have numpy 2.0.2 which is incompatible.
# tensorboard 2.10.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 5.28.3 which is incompatible.
# tensorflow 2.10.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 5.28.3 which is incompatible.
# Successfully installed backoff-2.2.1 bcrypt-4.2.1 build-1.2.2.post1 chroma-hnswlib-0.7.6 chromadb-0.5.20 coloredlogs-15.0.1 deprecated-1.2.15 durationpy-0.9 fastapi-0.115.5 fsspec-2024.10.0 grpcio-1.68.0 httptools-0.6.4 huggingface-hub-0.26.2 humanfriendly-10.0 importlib-metadata-8.5.0 importlib-resources-6.4.5 kubernetes-31.0.0 markdown-it-py-3.0.0 mdurl-0.1.2 mmh3-5.0.1 monotonic-1.6 numpy-2.0.2 oauthlib-3.2.2 onnxruntime-1.16.3 opentelemetry-api-1.28.2 opentelemetry-exporter-otlp-proto-common-1.28.2 opentelemetry-exporter-otlp-proto-grpc-1.28.2 opentelemetry-instrumentation-0.49b2 opentelemetry-instrumentation-asgi-0.49b2 opentelemetry-instrumentation-fastapi-0.49b2 opentelemetry-proto-1.28.2 opentelemetry-sdk-1.28.2 opentelemetry-semantic-conventions-0.49b2 opentelemetry-util-http-0.49b2 overrides-7.7.0 posthog-3.7.3 protobuf-5.28.3 pygments-2.18.0 pypika-0.48.9 pyproject_hooks-1.2.0 python-dotenv-1.0.1 rich-13.9.4 shellingham-1.5.4 starlette-0.41.3 tokenizers-0.20.4 tqdm-4.67.1 typer-0.13.1 uvicorn-0.32.1 uvloop-0.21.0 watchfiles-1.0.0 websockets-14.1 zipp-3.21.0
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
